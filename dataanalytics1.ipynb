# %%
import numpy as np
import pandas as pd
bookdata=pd.read_csv('/content/sample_data/california_housing_train.csv')
df = pd.DataFrame(bookdata)
df
df.mean()
df.loc[:,"population"].mean()
df.median()
df.mode()
import matplotlib.pyplot as plt
import scipy
from scipy import stats
scipy.stats.gmean(df.loc[:,"total_rooms"])

scipy.stats.hmean(df.loc[:,"total_bedrooms"])

scipy.stats.iqr(df.loc[:,"households"])
scipy.stats.iqr(df.loc[:,"population"])
ax1 = df.plot.scatter(x='longitude',y='latitude',c='DarkBlue')
bp=df.boxplot(column=["longitude","latitude"],showfliers=False)
df.hist(column="total_rooms")
df.hist(column=["total_rooms","total_bedrooms"])
df.plot.bar(x="total_rooms",y="total_bedrooms",rot=0)
